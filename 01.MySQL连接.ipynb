# %% [markdown]
# # MySQL连接

# %% [markdown]
# ## jupyter 魔法方法连接

# %%
# %load_ext sql

# %%
# %sql mysql+mysqlconnector://root:123456@localhost:3306/world

# %%
# %%sql
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/world
# 3 rows affected.
# [('city',), ('country',), ('countrylanguage',)]

# %%
# %%sql
# SHOW DATABASES;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/world
# 6 rows affected.
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('test',),
#  ('world',)]

# %%
# %%sql
# SELECT * FROM country LIMIT 5;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/world
# 5 rows affected.
# [('ABW', 'Aruba', 'North America', 'Caribbean', Decimal('193.00'), None, 103000, Decimal('78.4'), Decimal('828.00'), Decimal('793.00'), 'Aruba', 'Nonmetropolitan Territory of The Netherlands', 'Beatrix', 129, 'AW'),
#  ('AFG', 'Afghanistan', 'Asia', 'Southern and Central Asia', Decimal('652090.00'), 1919, 22720000, Decimal('45.9'), Decimal('5976.00'), None, 'Afganistan/Afqanestan', 'Islamic Emirate', 'Mohammad Omar', 1, 'AF'),
#  ('AGO', 'Angola', 'Africa', 'Central Africa', Decimal('1246700.00'), 1975, 12878000, Decimal('38.3'), Decimal('6648.00'), Decimal('7984.00'), 'Angola', 'Republic', 'José Eduardo dos Santos', 56, 'AO'),
#  ('AIA', 'Anguilla', 'North America', 'Caribbean', Decimal('96.00'), None, 8000, Decimal('76.1'), Decimal('63.20'), None, 'Anguilla', 'Dependent Territory of the UK', 'Elisabeth II', 62, 'AI'),
# ...

# %% [markdown]
# ## Python库连接

# %%
import mysql.connector

def sql(cmd):
    connection = mysql.connector.connect(
        host='localhost',
        port=3306,
        user='root',
        password='123456',
        database='world'  # 如果需要连接到特定数据库
    )

    cursor = connection.cursor()
    cursor.execute(cmd)
    for db in cursor.fetchall():
        print(db)

    cursor.close()
    connection.close()

# %%
sql('SHOW TABLES;')
# Out:
# ('city',)
# ('country',)
# ('countrylanguage',)

# %% [markdown]
# ## Pandas 连接

# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine

# %%
con = create_engine("mysql+mysqlconnector://root:123456@localhost:3306/world")

# %%
df = pd.read_sql("SELECT * FROM country ORDER BY Population DESC;", con)
df.head()
# Out:
#   Code           Name      Continent                     Region  SurfaceArea  \
# 0  CHN          China           Asia               Eastern Asia    9572900.0
# 1  IND          India           Asia  Southern and Central Asia    3287263.0
# 2  USA  United States  North America              North America    9363520.0
# 3  IDN      Indonesia           Asia             Southeast Asia    1904569.0
# 4  BRA         Brazil  South America              South America    8547403.0
#
#    IndepYear  Population  LifeExpectancy        GNP     GNPOld      LocalName  \
# 0    -1523.0  1277558000            71.4   982268.0   917719.0       Zhongquo
# 1     1947.0  1013662000            62.5   447114.0   430572.0   Bharat/India
# 2     1776.0   278357000            77.1  8510700.0  8110900.0  United States
# 3     1945.0   212107000            68.0    84982.0   215002.0      Indonesia
# 4     1822.0   170115000            62.9   776739.0   804108.0         Brasil
#
# ...

# %%
df.sort_values(by='SurfaceArea', ascending=False, inplace=True)
df.head()
# Out:
#     Code                Name      Continent          Region  SurfaceArea  \
# 6    RUS  Russian Federation         Europe  Eastern Europe   17075400.0
# 232  ATA          Antarctica     Antarctica      Antarctica   13120000.0
# 33   CAN              Canada  North America   North America    9970610.0
# 0    CHN               China           Asia    Eastern Asia    9572900.0
# 2    USA       United States  North America   North America    9363520.0
#
#      IndepYear  Population  LifeExpectancy        GNP     GNPOld  \
# 6       1991.0   146934000            67.2   276608.0   442989.0
# 232        NaN           0             NaN        0.0        NaN
# 33      1867.0    31147000            79.4   598862.0   625626.0
# 0      -1523.0  1277558000            71.4   982268.0   917719.0
# 2       1776.0   278357000            77.1  8510700.0  8110900.0
#
#          LocalName                       GovernmentForm     HeadOfState  \
# ...
